# %%
import matplotlib.pyplot as plt

# %%
n_threads = [2, 8, 32, 128]

mean_img_times = [
    [253.22, 310.17, 436.83, 278.56], # Pre-fetch - 4
    [267.20, 1113.78, 1214.71, 936.57], # Pre-fetch - 8
]

std_img_times = [
    [313.04, 293.96, 230.49, 156.01],
    [331.55, 399.47, 42.21, 82.94]
]

# %%
plt.errorbar(n_threads, mean_img_times[0], std_img_times[0], ecolor='gray', label='Prefetch 4 batches', capsize=1)
plt.errorbar(n_threads, mean_img_times[1], std_img_times[1], ecolor='gray', label='Prefetch 8 batches', capsize=1)
# Out:
# <ErrorbarContainer object of 3 artists>
